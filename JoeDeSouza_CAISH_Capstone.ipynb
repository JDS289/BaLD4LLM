# %% [markdown]
# <a href="https://colab.research.google.com/github/JDS289/BaLD4LLM/blob/main/JoeDeSouza_CAISH_Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualising the separation between true and false statements in an LLM

# %% [markdown]
# Building on fellowship readings about understanding Transformer architecture and latent knowledge, and the workshop on mechanistic interpretability, I wanted to see if I could get any concrete results (even if only small).
#
# In a paper (https://arxiv.org/pdf/2407.12831v1) that I'll be exploring in my dissertation this year, the authors claim that the activations of an LLM reading a statement convey linear information about whether the statement is true.
#
# Using Llama 3.1 8B, they produce this graph
#
# ![](https://drive.google.com/uc?export=view&id=1lKcBJ4PDutlbUKvxyKAaZpPOlXpW_x-o)
#
# showing the amount of difference in the activations (by layer) between True and False statements, when reading the final token of the statement.
#
# As a small concrete project, I wanted to see if I'd be able to produce a similar graph, from scratch, using Llama 3.2 3B.
#
# The outputs are shown - but hopefully this notebook can be re-run. Using "CPU" as the runtime type is slow; avoid using it (with GPU, loading the model takes a few minutes, and the rest also takes a few minutes).

# %%
import torch
from accelerate import Accelerator
from transformers import AutoModelForCausalLM, AutoTokenizer
import numpy as np
from tqdm.notebook import tqdm

from google.colab import userdata
hf_token = userdata.get("huggingface_secret")

from huggingface_hub import login
login(token=hf_token)

device = "cuda" if torch.cuda.is_available() else "cpu"
accelerator = Accelerator()

SYS_PROMPT = ""

# %%
model_name = "meta-llama/Llama-3.2-3B-Instruct"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    use_safetensors=True,
    device_map="auto",
    output_hidden_states=True,
    return_dict_in_generate=True,
)
# Out:
# config.json:   0%|          | 0.00/878 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, use_safetensors=True)
tokenizer.pad_token = tokenizer.eos_token
model, tokenizer = accelerator.prepare(model, tokenizer)

model.generation_config.output_hidden_states = True
model.generation_config.return_dict_in_generate = True
# Out:
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]

# %%
def process_chunk(text_chunk_batch):
    conversations = [[
        {"role": "system", "content": SYS_PROMPT},
        {"role": "user", "content": text_chunk}]
              for text_chunk in text_chunk_batch]

    prompt = tokenizer.apply_chat_template(conversations, tokenize=False)
    inputs = tokenizer(prompt, padding="max_length", padding_side="left", max_length=64, return_tensors="pt")
    inputs = inputs.to(accelerator.device)

    with torch.no_grad():
        output = model.generate(
            **inputs,
            temperature=0.01,
            top_p=0.9,
            max_new_tokens=5
        )
    # For answering yes/no questions like the following, extremely low temperature and max_new_tokens makes sense.
    # For this actual task its generations are not actually relevant, but they're helpful to see and might be useful later.

    processed_texts = tokenizer.batch_decode(output.sequences, skip_special_tokens=True)
    processed_texts = [text[text.index("assistant") + 10:].lstrip() for text in processed_texts]

    return processed_texts, output.hidden_states

# %% [markdown]
# A simple way to generate (generally) unambiguous statements is "*{Capital}* is the capital of *{Country}*".
# With corresponding lists of each, we can generate false statements by just rotating

# %%
import requests

# Manually sorted through these to try to remove anything ambiguous/contested
capitals = requests.get("https://raw.githubusercontent.com/JDS289/BaLD4LLM/refs/heads/main/country-list.csv")
capitals_dict = {}
for string in capitals.content.decode('utf-8').split('\n')[1 : -1]:
  _, country, _, city, _ = string.split('"')
  capitals_dict[country] = city

print("\n".join(f"{key}: {value}" for key, value in capitals_dict.items()))
# Out:
# Afghanistan: Kabul
# Albania: Tirana
# Algeria: Algiers
# Andorra: Andorra la Vella
# Angola: Luanda
# Antigua and Barbuda: St. John's
# Argentina: Buenos Aires
# Armenia: Yerevan
# Australia: Canberra
# Austria: Vienna
# Azerbaijan: Baku
# Bahamas: Nassau
# Bahrain: Manama
# Bangladesh: Dhaka
# Barbados: Bridgetown
# Belarus: Minsk
# Belgium: Brussels
# Belize: Belmopan
# Benin: Porto-Novo
# Bhutan: Thimphu
# Bosnia and Herzegovina: Sarajevo
# Botswana: Gaborone
# Brazil: Brasília
# Brunei: Bandar Seri Begawan
# Bulgaria: Sofia
# Burkina Faso: Ouagadougou
# Burundi: Bujumbura
# Cambodia: Phnom Penh
# Cameroon: Yaoundé
# Canada: Ottawa
# Cape Verde: Praia
# Central African Republic: Bangui
# Chad: N'Djamena
# Chile: Santiago
# China: Beijing
# Colombia: Bogotá
# Comoros: Moroni
# Costa Rica: San José
# Croatia: Zagreb
# Cuba: Havana
# Cyprus: Nicosia
# Côte d'Ivoire: Yamoussoukro
# Democratic Republic of the Congo: Kinshasa
# Denmark: Copenhagen
# Djibouti: Djibouti
# Dominica: Roseau
# Dominican Republic: Santo Domingo
# East Timor: Dili
# Ecuador: Quito
# Egypt: Cairo
# El Salvador: San Salvador
# Equatorial Guinea: Malabo
# Eritrea: Asmara
# Estonia: Tallinn
# Ethiopia: Addis Ababa
# Federated States of Micronesia: Palikir
# Fiji: Suva
# Finland: Helsinki
# France: Paris
# Gabon: Libreville
# Gambia: Banjul
# Georgia: Tbilisi
# Germany: Berlin
# Ghana: Accra
# Greece: Athens
# Grenada: St. George's
# Guatemala: Guatemala City
# Guinea: Conakry
# Guinea-Bissau: Bissau
# Guyana: Georgetown
# Haiti: Port-au-Prince
# Honduras: Tegucigalpa
# Hungary: Budapest
# Iceland: Reykjavík
# India: New Delhi
# Indonesia: Jakarta
# Iran: Tehran
# Iraq: Baghdad
# Ireland: Dublin
# Italy: Rome
# Jamaica: Kingston
# Japan: Tokyo
# Jordan: Amman
# Kazakhstan: Astana
# Kenya: Nairobi
# Kiribati: Tarawa
# Kosovo: Pristina
# Kuwait: Kuwait City
# Kyrgyzstan: Bishkek
# Laos: Vientiane
# Latvia: Riga
# Lebanon: Beirut
# Lesotho: Maseru
# Liberia: Monrovia
# Libya: Tripoli
# Liechtenstein: Vaduz
# Lithuania: Vilnius
# Luxembourg: Luxembourg
# Madagascar: Antananarivo
# Malawi: Lilongwe
# Malaysia: Kuala Lumpur
# Maldives: Malé
# Mali: Bamako
# Malta: Valletta
# Marshall Islands: Majuro
# Mauritania: Nouakchott
# Mauritius: Port Louis
# Mexico: Mexico City
# Moldova: Chisinau
# Monaco: Monaco
# Mongolia: Ulaanbaatar
# Montenegro: Podgorica
# Morocco: Rabat
# Mozambique: Maputo
# Myanmar: Naypyidaw
# Namibia: Windhoek
# Nauru: Yaren
# Nepal: Kathmandu
# Netherlands: Amsterdam
# New Zealand: Wellington
# Nicaragua: Managua
# Niger: Niamey
# Nigeria: Abuja
# North Korea: Pyongyang
# Norway: Oslo
# Oman: Muscat
# Pakistan: Islamabad
# Palau: Ngerulmud
# Panama: Panama City
# Papua New Guinea: Port Moresby
# Paraguay: Asunción
# Peru: Lima
# Philippines: Manila
# Poland: Warsaw
# Portugal: Lisbon
# Qatar: Doha
# Republic of the Congo: Brazzaville
# Romania: Bucharest
# Russia: Moscow
# Rwanda: Kigali
# Saint Kitts and Nevis: Basseterre
# Saint Lucia: Castries
# Saint Vincent and the Grenadines: Kingstown
# Samoa: Apia
# San Marino: San Marino
# Saudi Arabia: Riyadh
# Senegal: Dakar
# Serbia: Belgrade
# Seychelles: Victoria
# Sierra Leone: Freetown
# Singapore: Singapore
# Slovakia: Bratislava
# Slovenia: Ljubljana
# Solomon Islands: Honiara
# Somalia: Mogadishu
# South Korea: Seoul
# Spain: Madrid
# Sudan: Khartoum
# Suriname: Paramaribo
# Sweden: Stockholm
# Switzerland: Bern
# Syria: Damascus
# São Tomé and Príncipe: São Tomé
# Tajikistan: Dushanbe
# Tanzania: Dodoma
# Thailand: Bangkok
# Togo: Lomé
# Tonga: Nukuʻalofa
# Trinidad and Tobago: Port of Spain
# Tunisia: Tunis
# Turkey: Ankara
# Turkmenistan: Ashgabat
# Tuvalu: Funafuti
# Uganda: Kampala
# Ukraine: Kyiv
# United Arab Emirates: Abu Dhabi
# United Kingdom: London
# United States: Washington, D.C.
# Uruguay: Montevideo
# Uzbekistan: Tashkent
# Vanuatu: Port Vila
# Vatican City: Vatican City
# Venezuela: Caracas
# Vietnam: Hanoi
# Yemen: Sanaá
# Zambia: Lusaka
# Zimbabwe: Harare

# %%
true_list = [f"Is {capital} the capital of {country}?" for country, capital in capitals_dict.items()]
fixed_order_capitals_dict = list(capitals_dict.items())
false_list = [f"Is {fixed_order_capitals_dict[i][1]} the capital of {fixed_order_capitals_dict[(i+1) % len(capitals_dict)][0]}?" for i in range(len(capitals_dict))]
print(true_list[:10], false_list[:10])

def print_ret(x):
  print(x[:2])
  return x

results = [print_ret((q,) + process_chunk(q)) for q in tqdm(true_list)]
results_false = [print_ret((q,) + process_chunk(q)) for q in tqdm(false_list)]
# Out:
# ['Is Kabul the capital of Afghanistan?', 'Is Tirana the capital of Albania?', 'Is Algiers the capital of Algeria?', 'Is Andorra la Vella the capital of Andorra?', 'Is Luanda the capital of Angola?', "Is St. John's the capital of Antigua and Barbuda?", 'Is Buenos Aires the capital of Argentina?', 'Is Yerevan the capital of Armenia?', 'Is Canberra the capital of Australia?', 'Is Vienna the capital of Austria?'] ['Is Kabul the capital of Albania?', 'Is Tirana the capital of Algeria?', 'Is Algiers the capital of Andorra?', 'Is Andorra la Vella the capital of Angola?', 'Is Luanda the capital of Antigua and Barbuda?', "Is St. John's the capital of Argentina?", 'Is Buenos Aires the capital of Armenia?', 'Is Yerevan the capital of Australia?', 'Is Canberra the capital of Austria?', 'Is Vienna the capital of Azerbaijan?']
#   0%|          | 0/187 [00:00<?, ?it/s]
# ('Is Kabul the capital of Afghanistan?', '\nYes')
# ('Is Tirana the capital of Albania?', '\nYes')
# ('Is Algiers the capital of Algeria?', '\nYes')
# ('Is Andorra la Vella the capital of Andorra?', '\nYes')
# ('Is Luanda the capital of Angola?', '\nYes')
# ("Is St. John's the capital of Antigua and Barbuda?", '\nSt')
# ('Is Buenos Aires the capital of Argentina?', '\nYes')
# ('Is Yerevan the capital of Armenia?', '\nYes')
# ('Is Canberra the capital of Australia?', '\nYes')
# ('Is Vienna the capital of Austria?', '\nYes')
# ('Is Baku the capital of Azerbaijan?', '\nYes')
# ('Is Nassau the capital of Bahamas?', '\nYes')
# ('Is Manama the capital of Bahrain?', '\nYes')
# ('Is Dhaka the capital of Bangladesh?', '\nYes')
# ('Is Bridgetown the capital of Barbados?', '\nYes')
# ('Is Minsk the capital of Belarus?', '\nYes')
# ('Is Brussels the capital of Belgium?', '\nYes')
# ('Is Belmopan the capital of Belize?', '\nNo')
# ('Is Porto-Novo the capital of Benin?', '\nNo')
# ('Is Thimphu the capital of Bhutan?', '\nYes')
# ('Is Sarajevo the capital of Bosnia and Herzegovina?', '\nYes')
# ('Is Gaborone the capital of Botswana?', '\nYes')
# ('Is Brasília the capital of Brazil?', '\nYes')
# ('Is Bandar Seri Begawan the capital of Brunei?', '\nYes')
# ('Is Sofia the capital of Bulgaria?', '\nYes')
# ('Is Ouagadougou the capital of Burkina Faso?', '\nYes')
# ('Is Bujumbura the capital of Burundi?', '\nNo')
# ('Is Phnom Penh the capital of Cambodia?', '\nYes')
# ('Is Yaoundé the capital of Cameroon?', '\nYes')
# ('Is Ottawa the capital of Canada?', '\nYes')
# ('Is Praia the capital of Cape Verde?', '\nNo')
# ('Is Bangui the capital of Central African Republic?', '\nYes')
# ("Is N'Djamena the capital of Chad?", '\nYes')
# ('Is Santiago the capital of Chile?', '\nYes')
# ('Is Beijing the capital of China?', '\nYes')
# ('Is Bogotá the capital of Colombia?', '\nYes')
# ('Is Moroni the capital of Comoros?', '\nNo')
# ('Is San José the capital of Costa Rica?', '\nYes')
# ('Is Zagreb the capital of Croatia?', '\nYes')
# ('Is Havana the capital of Cuba?', '\nYes')
# ('Is Nicosia the capital of Cyprus?', '\nYes')
# ("Is Yamoussoukro the capital of Côte d'Ivoire?", '\nNo')
# ('Is Kinshasa the capital of Democratic Republic of the Congo?', '\nYes')
# ('Is Copenhagen the capital of Denmark?', '\nYes')
# ('Is Djibouti the capital of Djibouti?', '\nYes')
# ('Is Roseau the capital of Dominica?', '\nYes')
# ('Is Santo Domingo the capital of Dominican Republic?', '\nYes')
# ('Is Dili the capital of East Timor?', '\nYes')
# ('Is Quito the capital of Ecuador?', '\nYes')
# ('Is Cairo the capital of Egypt?', '\nYes')
# ('Is San Salvador the capital of El Salvador?', '\nYes')
# ('Is Malabo the capital of Equatorial Guinea?', '\nYes')
# ('Is Asmara the capital of Eritrea?', '\nYes')
# ('Is Tallinn the capital of Estonia?', '\nYes')
# ('Is Addis Ababa the capital of Ethiopia?', '\nYes')
# ('Is Palikir the capital of Federated States of Micronesia?', '\nYes')
# ('Is Suva the capital of Fiji?', '\nYes')
# ('Is Helsinki the capital of Finland?', '\nYes')
# ('Is Paris the capital of France?', '\nYes')
# ('Is Libreville the capital of Gabon?', '\nYes')
# ('Is Banjul the capital of Gambia?', '\nYes')
# ('Is Tbilisi the capital of Georgia?', '\nYes')
# ('Is Berlin the capital of Germany?', '\nYes')
# ('Is Accra the capital of Ghana?', '\nYes')
# ('Is Athens the capital of Greece?', '\nYes')
# ("Is St. George's the capital of Grenada?", '\nNo')
# ('Is Guatemala City the capital of Guatemala?', '\nYes')
# ('Is Conakry the capital of Guinea?', '\nYes')
# ('Is Bissau the capital of Guinea-Bissau?', '\nYes')
# ('Is Georgetown the capital of Guyana?', '\nNo')
# ('Is Port-au-Prince the capital of Haiti?', '\nYes')
# ('Is Tegucigalpa the capital of Honduras?', '\nYes')
# ('Is Budapest the capital of Hungary?', '\nYes')
# ('Is Reykjavík the capital of Iceland?', '\nYes')
# ('Is New Delhi the capital of India?', '\nYes')
# ('Is Jakarta the capital of Indonesia?', '\nYes')
# ('Is Tehran the capital of Iran?', '\nYes')
# ('Is Baghdad the capital of Iraq?', '\nYes')
# ('Is Dublin the capital of Ireland?', '\nYes')
# ('Is Rome the capital of Italy?', '\nYes')
# ('Is Kingston the capital of Jamaica?', '\nYes')
# ('Is Tokyo the capital of Japan?', '\nYes')
# ('Is Amman the capital of Jordan?', '\nYes')
# ('Is Astana the capital of Kazakhstan?', '\nYes')
# ('Is Nairobi the capital of Kenya?', '\nYes')
# ('Is Tarawa the capital of Kiribati?', '\nNo')
# ('Is Pristina the capital of Kosovo?', '\nYes')
# ('Is Kuwait City the capital of Kuwait?', '\nYes')
# ('Is Bishkek the capital of Kyrgyzstan?', '\nYes')
# ('Is Vientiane the capital of Laos?', '\nYes')
# ('Is Riga the capital of Latvia?', '\nYes')
# ('Is Beirut the capital of Lebanon?', '\nYes')
# ('Is Maseru the capital of Lesotho?', '\nYes')
# ('Is Monrovia the capital of Liberia?', '\nYes')
# ('Is Tripoli the capital of Libya?', '\nYes')
# ('Is Vaduz the capital of Liechtenstein?', '\nYes')
# ('Is Vilnius the capital of Lithuania?', '\nYes')
# ('Is Luxembourg the capital of Luxembourg?', '\nYes')
# ('Is Antananarivo the capital of Madagascar?', '\nYes')
# ('Is Lilongwe the capital of Malawi?', '\nYes')
# ('Is Kuala Lumpur the capital of Malaysia?', '\nYes')
# ('Is Malé the capital of Maldives?', '\nYes')
# ('Is Bamako the capital of Mali?', '\nNo')
# ('Is Valletta the capital of Malta?', '\nYes')
# ('Is Majuro the capital of Marshall Islands?', '\nYes')
# ('Is Nouakchott the capital of Mauritania?', '\nNo')
# ('Is Port Louis the capital of Mauritius?', '\nYes')
# ('Is Mexico City the capital of Mexico?', '\nYes')
# ('Is Chisinau the capital of Moldova?', '\nYes')
# ('Is Monaco the capital of Monaco?', '\nYes')
# ('Is Ulaanbaatar the capital of Mongolia?', '\nYes')
# ('Is Podgorica the capital of Montenegro?', '\nYes')
# ('Is Rabat the capital of Morocco?', '\nYes')
# ('Is Maputo the capital of Mozambique?', '\nYes')
# ('Is Naypyidaw the capital of Myanmar?', '\nYes')
# ('Is Windhoek the capital of Namibia?', '\nYes')
# ('Is Yaren the capital of Nauru?', '\nYes')
# ('Is Kathmandu the capital of Nepal?', '\nYes')
# ('Is Amsterdam the capital of Netherlands?', '\nNo')
# ('Is Wellington the capital of New Zealand?', '\nYes')
# ('Is Managua the capital of Nicaragua?', '\nYes')
# ('Is Niamey the capital of Niger?', '\nYes')
# ('Is Abuja the capital of Nigeria?', '\nYes')
# ('Is Pyongyang the capital of North Korea?', '\nYes')
# ('Is Oslo the capital of Norway?', '\nYes')
# ('Is Muscat the capital of Oman?', '\nYes')
# ('Is Islamabad the capital of Pakistan?', '\nYes')
# ('Is Ngerulmud the capital of Palau?', '\nN')
# ('Is Panama City the capital of Panama?', '\nYes')
# ('Is Port Moresby the capital of Papua New Guinea?', '\nYes')
# ('Is Asunción the capital of Paraguay?', '\nYes')
# ('Is Lima the capital of Peru?', '\nYes')
# ('Is Manila the capital of Philippines?', '\nYes')
# ('Is Warsaw the capital of Poland?', '\nYes')
# ('Is Lisbon the capital of Portugal?', '\nYes')
# ('Is Doha the capital of Qatar?', '\nYes')
# ('Is Brazzaville the capital of Republic of the Congo?', '\nNo')
# ('Is Bucharest the capital of Romania?', '\nYes')
# ('Is Moscow the capital of Russia?', '\nYes')
# ('Is Kigali the capital of Rwanda?', '\nYes')
# ('Is Basseterre the capital of Saint Kitts and Nevis?', '\nYes')
# ('Is Castries the capital of Saint Lucia?', '\nYes')
# ('Is Kingstown the capital of Saint Vincent and the Grenadines?', '\nYes')
# ('Is Apia the capital of Samoa?', '\nYes')
# ('Is San Marino the capital of San Marino?', '\nNo')
# ('Is Riyadh the capital of Saudi Arabia?', '\nYes')
# ('Is Dakar the capital of Senegal?', '\nNo')
# ('Is Belgrade the capital of Serbia?', '\nYes')
# ('Is Victoria the capital of Seychelles?', '\nVictoria')
# ('Is Freetown the capital of Sierra Leone?', '\nYes')
# ('Is Singapore the capital of Singapore?', '\nYes')
# ('Is Bratislava the capital of Slovakia?', '\nYes')
# ('Is Ljubljana the capital of Slovenia?', '\nYes')
# ('Is Honiara the capital of Solomon Islands?', '\nYes')
# ('Is Mogadishu the capital of Somalia?', '\nYes')
# ('Is Seoul the capital of South Korea?', '\nYes')
# ('Is Madrid the capital of Spain?', '\nYes')
# ('Is Khartoum the capital of Sudan?', '\nYes')
# ('Is Paramaribo the capital of Suriname?', '\nYes')
# ('Is Stockholm the capital of Sweden?', '\nYes')
# ('Is Bern the capital of Switzerland?', '\nNo')
# ('Is Damascus the capital of Syria?', '\nNo')
# ('Is São Tomé the capital of São Tomé and Príncipe?', '\nYes')
# ('Is Dushanbe the capital of Tajikistan?', '\nYes')
# ('Is Dodoma the capital of Tanzania?', '\nYes')
# ('Is Bangkok the capital of Thailand?', '\nYes')
# ('Is Lomé the capital of Togo?', '\nL')
# ('Is Nukuʻalofa the capital of Tonga?', '\nYes')
# ('Is Port of Spain the capital of Trinidad and Tobago?', '\nNo')
# ('Is Tunis the capital of Tunisia?', '\nYes')
# ('Is Ankara the capital of Turkey?', '\nYes')
# ('Is Ashgabat the capital of Turkmenistan?', '\nYes')
# ('Is Funafuti the capital of Tuvalu?', '\nNo')
# ('Is Kampala the capital of Uganda?', '\nYes')
# ('Is Kyiv the capital of Ukraine?', '\nYes')
# ('Is Abu Dhabi the capital of United Arab Emirates?', '\nYes')
# ('Is London the capital of United Kingdom?', '\nYes')
# ('Is Washington, D.C. the capital of United States?', '\nYes')
# ('Is Montevideo the capital of Uruguay?', '\nYes')
# ('Is Tashkent the capital of Uzbekistan?', '\nYes')
# ('Is Port Vila the capital of Vanuatu?', '\nYes')
# ('Is Vatican City the capital of Vatican City?', '\nYes')
# ('Is Caracas the capital of Venezuela?', '\nYes')
# ('Is Hanoi the capital of Vietnam?', '\nNo')
# ('Is Sanaá the capital of Yemen?', '\nNo')
# ('Is Lusaka the capital of Zambia?', '\nYes')
# ('Is Harare the capital of Zimbabwe?', '\nYes')
#   0%|          | 0/187 [00:00<?, ?it/s]
# ('Is Kabul the capital of Albania?', 'No')
# ('Is Tirana the capital of Algeria?', 'No')
# ('Is Algiers the capital of Andorra?', '\nNo')
# ('Is Andorra la Vella the capital of Angola?', 'No')
# ('Is Luanda the capital of Antigua and Barbuda?', '\nNo')
# ("Is St. John's the capital of Argentina?", '\nNo')
# ('Is Buenos Aires the capital of Armenia?', 'No')
# ('Is Yerevan the capital of Australia?', '\nNo')
# ('Is Canberra the capital of Austria?', '\nNo')
# ('Is Vienna the capital of Azerbaijan?', '\nNo')
# ('Is Baku the capital of Bahamas?', '\nNo')
# ('Is Nassau the capital of Bahrain?', '\nYes')
# ('Is Manama the capital of Bangladesh?', '\nNo')
# ('Is Dhaka the capital of Barbados?', 'No')
# ('Is Bridgetown the capital of Belarus?', '\nNo')
# ('Is Minsk the capital of Belgium?', '\nNo')
# ('Is Brussels the capital of Belize?', '\nNo')
# ('Is Belmopan the capital of Benin?', 'No')
# ('Is Porto-Novo the capital of Bhutan?', '\nNo')
# ('Is Thimphu the capital of Bosnia and Herzegovina?', 'No')
# ('Is Sarajevo the capital of Botswana?', 'No')
# ('Is Gaborone the capital of Brazil?', 'No')
# ('Is Brasília the capital of Brunei?', '\nNo')
# ('Is Bandar Seri Begawan the capital of Bulgaria?', '\nNo')
# ('Is Sofia the capital of Burkina Faso?', '\nNo')
# ('Is Ouagadougou the capital of Burundi?', '\nNo')
# ('Is Bujumbura the capital of Cambodia?', 'No')
# ('Is Phnom Penh the capital of Cameroon?', 'No')
# ('Is Yaoundé the capital of Canada?', 'No')
# ('Is Ottawa the capital of Cape Verde?', '\nNo')
# ('Is Praia the capital of Central African Republic?', '\nNo')
# ('Is Bangui the capital of Chad?', '\nYes')
# ("Is N'Djamena the capital of Chile?", 'No')
# ('Is Santiago the capital of China?', '\nNo')
# ('Is Beijing the capital of Colombia?', 'No')
# ('Is Bogotá the capital of Comoros?', '\nNo')
# ('Is Moroni the capital of Costa Rica?', '\nNo')
# ('Is San José the capital of Croatia?', '\nNo')
# ('Is Zagreb the capital of Cuba?', '\nNo')
# ('Is Havana the capital of Cyprus?', '\nNo')
# ("Is Nicosia the capital of Côte d'Ivoire?", 'No')
# ('Is Yamoussoukro the capital of Democratic Republic of the Congo?', 'No')
# ('Is Kinshasa the capital of Denmark?', 'No')
# ('Is Copenhagen the capital of Djibouti?', '\nNo')
# ('Is Djibouti the capital of Dominica?', 'No')
# ('Is Roseau the capital of Dominican Republic?', '\nNo')
# ('Is Santo Domingo the capital of East Timor?', '\nNo')
# ('Is Dili the capital of Ecuador?', '\nNo')
# ('Is Quito the capital of Egypt?', '\nNo')
# ('Is Cairo the capital of El Salvador?', '\nNo')
# ('Is San Salvador the capital of Equatorial Guinea?', '\nNo')
# ('Is Malabo the capital of Eritrea?', '\nNo')
# ('Is Asmara the capital of Estonia?', '\nNo')
# ('Is Tallinn the capital of Ethiopia?', '\nNo')
# ('Is Addis Ababa the capital of Federated States of Micronesia?', 'No')
# ('Is Palikir the capital of Fiji?', '\nNo')
# ('Is Suva the capital of Finland?', '\nNo')
# ('Is Helsinki the capital of France?', '\nNo')
# ('Is Paris the capital of Gabon?', '\nNo')
# ('Is Libreville the capital of Gambia?', '\nNo')
# ('Is Banjul the capital of Georgia?', 'No')
# ('Is Tbilisi the capital of Germany?', '\nNo')
# ('Is Berlin the capital of Ghana?', '\nNo')
# ('Is Accra the capital of Greece?', '\nNo')
# ('Is Athens the capital of Grenada?', '\nNo')
# ("Is St. George's the capital of Guatemala?", '\nNo')
# ('Is Guatemala City the capital of Guinea?', '\nNo')
# ('Is Conakry the capital of Guinea-Bissau?', '\nNo')
# ('Is Bissau the capital of Guyana?', 'No')
# ('Is Georgetown the capital of Haiti?', '\nNo')
# ('Is Port-au-Prince the capital of Honduras?', 'No')
# ('Is Tegucigalpa the capital of Hungary?', 'No')
# ('Is Budapest the capital of Iceland?', 'No')
# ('Is Reykjavík the capital of India?', '\nNo')
# ('Is New Delhi the capital of Indonesia?', 'No')
# ('Is Jakarta the capital of Iran?', '\nNo')
# ('Is Tehran the capital of Iraq?', '\nNo')
# ('Is Baghdad the capital of Ireland?', '\nNo')
# ('Is Dublin the capital of Italy?', '\nNo')
# ('Is Rome the capital of Jamaica?', '\nNo')
# ('Is Kingston the capital of Japan?', '\nNo')
# ('Is Tokyo the capital of Jordan?', '\nNo')
# ('Is Amman the capital of Kazakhstan?', '\nNo')
# ('Is Astana the capital of Kenya?', '\nNo')
# ('Is Nairobi the capital of Kiribati?', '\nNo')
# ('Is Tarawa the capital of Kosovo?', '\nNo')
# ('Is Pristina the capital of Kuwait?', '\nNo')
# ('Is Kuwait City the capital of Kyrgyzstan?', 'No')
# ('Is Bishkek the capital of Laos?', 'No')
# ('Is Vientiane the capital of Latvia?', 'No')
# ('Is Riga the capital of Lebanon?', '\nNo')
# ('Is Beirut the capital of Lesotho?', '\nNo')
# ('Is Maseru the capital of Liberia?', '\nNo')
# ('Is Monrovia the capital of Libya?', '\nNo')
# ('Is Tripoli the capital of Liechtenstein?', 'No')
# ('Is Vaduz the capital of Lithuania?', 'No')
# ('Is Vilnius the capital of Luxembourg?', 'No')
# ('Is Luxembourg the capital of Madagascar?', '\nNo')
# ('Is Antananarivo the capital of Malawi?', '\nNo')
# ('Is Lilongwe the capital of Malaysia?', 'No')
# ('Is Kuala Lumpur the capital of Maldives?', 'No')
# ('Is Malé the capital of Mali?', '\nNo')
# ('Is Bamako the capital of Malta?', 'No')
# ('Is Valletta the capital of Marshall Islands?', '\nNo')
# ('Is Majuro the capital of Mauritania?', '\nNo')
# ('Is Nouakchott the capital of Mauritius?', '\nNo')
# ('Is Port Louis the capital of Mexico?', 'No')
# ('Is Mexico City the capital of Moldova?', '\nNo')
# ('Is Chisinau the capital of Monaco?', 'No')
# ('Is Monaco the capital of Mongolia?', '\nNo')
# ('Is Ulaanbaatar the capital of Montenegro?', 'No')
# ('Is Podgorica the capital of Morocco?', 'No')
# ('Is Rabat the capital of Mozambique?', '\nNo')
# ('Is Maputo the capital of Myanmar?', '\nNo')
# ('Is Naypyidaw the capital of Namibia?', 'No')
# ('Is Windhoek the capital of Nauru?', '\nNo')
# ('Is Yaren the capital of Nepal?', '\nNo')
# ('Is Kathmandu the capital of Netherlands?', 'No')
# ('Is Amsterdam the capital of New Zealand?', 'No')
# ('Is Wellington the capital of Nicaragua?', '\nNo')
# ('Is Managua the capital of Niger?', '\nNo')
# ('Is Niamey the capital of Nigeria?', 'No')
# ('Is Abuja the capital of North Korea?', 'No')
# ('Is Pyongyang the capital of Norway?', '\nNo')
# ('Is Oslo the capital of Oman?', '\nNo')
# ('Is Muscat the capital of Pakistan?', '\nNo')
# ('Is Islamabad the capital of Palau?', '\nNo')
# ('Is Ngerulmud the capital of Panama?', '\nNo')
# ('Is Panama City the capital of Papua New Guinea?', 'No')
# ('Is Port Moresby the capital of Paraguay?', 'No')
# ('Is Asunción the capital of Peru?', '\nNo')
# ('Is Lima the capital of Philippines?', '\nNo')
# ('Is Manila the capital of Poland?', '\nNo')
# ('Is Warsaw the capital of Portugal?', '\nNo')
# ('Is Lisbon the capital of Qatar?', '\nNo')
# ('Is Doha the capital of Republic of the Congo?', '\nNo')
# ('Is Brazzaville the capital of Romania?', 'No')
# ('Is Bucharest the capital of Russia?', '\nNo')
# ('Is Moscow the capital of Rwanda?', '\nNo')
# ('Is Kigali the capital of Saint Kitts and Nevis?', '\nNo')
# ('Is Basseterre the capital of Saint Lucia?', '\nYes')
# ('Is Castries the capital of Saint Vincent and the Grenadines?', '\nNo')
# ('Is Kingstown the capital of Samoa?', '\nNo')
# ('Is Apia the capital of San Marino?', '\nNo')
# ('Is San Marino the capital of Saudi Arabia?', '\nNo')
# ('Is Riyadh the capital of Senegal?', '\nNo')
# ('Is Dakar the capital of Serbia?', '\nNo')
# ('Is Belgrade the capital of Seychelles?', '\nNo')
# ('Is Victoria the capital of Sierra Leone?', '\nNo')
# ('Is Freetown the capital of Singapore?', 'No')
# ('Is Singapore the capital of Slovakia?', '\nNo')
# ('Is Bratislava the capital of Slovenia?', 'No')
# ('Is Ljubljana the capital of Solomon Islands?', 'No')
# ('Is Honiara the capital of Somalia?', '\nNo')
# ('Is Mogadishu the capital of South Korea?', '\nNo')
# ('Is Seoul the capital of Spain?', '\nNo')
# ('Is Madrid the capital of Sudan?', '\nNo')
# ('Is Khartoum the capital of Suriname?', '\nNo')
# ('Is Paramaribo the capital of Sweden?', '\nNo')
# ('Is Stockholm the capital of Switzerland?', 'No')
# ('Is Bern the capital of Syria?', '\nNo')
# ('Is Damascus the capital of São Tomé and Príncipe?', '\nNo')
# ('Is São Tomé the capital of Tajikistan?', '\nNo')
# ('Is Dushanbe the capital of Tanzania?', 'No')
# ('Is Dodoma the capital of Thailand?', 'No')
# ('Is Bangkok the capital of Togo?', 'No')
# ('Is Lomé the capital of Tonga?', '\nNo')
# ('Is Nukuʻalofa the capital of Trinidad and Tobago?', '\nNo')
# ('Is Port of Spain the capital of Tunisia?', 'No')
# ('Is Tunis the capital of Turkey?', 'No')
# ('Is Ankara the capital of Turkmenistan?', '\nNo')
# ('Is Ashgabat the capital of Tuvalu?', '\nNo')
# ('Is Funafuti the capital of Uganda?', '\nNo')
# ('Is Kampala the capital of Ukraine?', 'No')
# ('Is Kyiv the capital of United Arab Emirates?', '\nNo')
# ('Is Abu Dhabi the capital of United Kingdom?', 'No')
# ('Is London the capital of United States?', 'No')
# ('Is Washington, D.C. the capital of Uruguay?', '\nNo')
# ('Is Montevideo the capital of Uzbekistan?', 'No')
# ('Is Tashkent the capital of Vanuatu?', '\nNo')
# ('Is Port Vila the capital of Vatican City?', 'No')
# ('Is Vatican City the capital of Venezuela?', '\nNo')
# ('Is Caracas the capital of Vietnam?', 'No')
# ('Is Hanoi the capital of Yemen?', '\nNo')
# ('Is Sanaá the capital of Zambia?', '\nNo')
# ('Is Lusaka the capital of Zimbabwe?', '\nNo')
# ('Is Harare the capital of Afghanistan?', '\nNo')
